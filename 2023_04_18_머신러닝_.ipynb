# %% [markdown]
# <a href="https://colab.research.google.com/github/chldkduds2/2023-schoolAiMachineLearning/blob/main/2023_04_18_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
plt.rc('font', family='NanumBarunGothic')


plt.style.use('ggplot')
fig=plt.figure(figsize=(10,5))
ax=fig.add_subplot() 
bar_width = 0.25

df = pd.read_csv('/content/1군전염병발병현황_년도별.csv',encoding='cp949')
nrow = df.shape[0]
index = np.arange(nrow)


b1 = plt.bar(index-bar_width, df['콜레라'], bar_width, color="red", label='콜레라')
b2 = plt.bar(index, df['장티푸스'], bar_width, color="blue", label='장티푸스')
b3 = plt.bar(index+bar_width, df['이질'], bar_width, color="purple", label='이질')
b4 = plt.bar(index+bar_width*2, df['대장균'], bar_width, color="black", label='대장균')


plt.legend()
plt.xticks(index, df['년도'])
plt.ylabel('발생 건수')


plt.show()

# %%
import csv
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt


plt.rc('font', family='NanumBarunGothic')


f = open('/content/1군전염병발병현황_년도별.csv', 'r', encoding='cp949')

rdr = csv.reader(f)


df = pd.DataFrame(rdr)


df.rename(mapper = df.iloc[0], axis=1, inplace = True)

df.drop([0], axis=0, inplace=True)


df['콜레라'] = df['콜레라'].apply(int)

df['장티푸스'] = df['장티푸스'].apply(int)

df['이질'] = df['이질'].apply(int)

df['대장균'] = df['대장균'].apply(int)


fig, ax = plt.subplots(figsize=(15,5))

bar_width = 0.15


year = np.arange(2002, 2013)


b1 = plt.bar(year-bar_width, df['콜레라'], bar_width, alpha=0.4, color='red', label='콜레라')

b2 = plt.bar(year, df['장티푸스'], bar_width, alpha=0.4, color='blue', label='장티푸스')

b3 = plt.bar(year + bar_width, df['이질'], bar_width, alpha=0.4, color='green', label='이질')

b4 = plt.bar(year + bar_width * 2, df['대장균'], bar_width, alpha=0.4, color='yellow', label='대장균')

plt.legend()
plt.xticks(year, df['년도'])

plt.show()
f.close()
